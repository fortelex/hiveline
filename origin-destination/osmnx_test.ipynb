# %%
import geopandas as gpd
import osmnx as ox

# %%
place_name = 'Konstanz, Germany'
city = ox.geocode_to_gdf(place_name)
ax = ox.copy().project_gdf(city).plot()
_ = ax.axis('off')

# %%
G=ox.graph_from_place(place_name, network_type='all', retain_all=True)
ox.plot_graph(G)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
basic_stats = ox.basic_stats(G)
basic_stats
# Out:
# {'n': 10328,
#  'm': 26809,
#  'k_avg': 5.191518202943454,
#  'edge_length_total': 1595610.382000007,
#  'edge_length_avg': 59.517713529039014,
#  'streets_per_node_avg': 2.745739736638265,
#  'streets_per_node_counts': {0: 0,
#   1: 2017,
#   2: 35,
#   3: 6901,
#   4: 1319,
#   5: 44,
#   6: 12},
#  'streets_per_node_proportions': {0: 0.0,
#   1: 0.19529434546862898,
#   2: 0.003388845855925639,
#   3: 0.6681835786212239,
#   4: 0.12771107668474052,
#   5: 0.004260263361735089,
#   6: 0.0011618900077459333},
#  'intersection_count': 8311,
#  'street_length_total': 830628.2290000007,
#  'street_segment_count': 14116,
#  'street_length_avg': 58.84303124114485,
#  'circuity_avg': 1.0652442072647805,
#  'self_loop_proportion': 0.001700198356474922}

# %%
tags = {'landuse': ['residential','commercial']}   

buildings = ox.geometries_from_place(place_name, tags)
buildings.plot()
# Out:
# /tmp/ipykernel_1771953/1535114145.py:3: UserWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in a future release.
#   buildings = ox.geometries_from_place(place_name, tags)
# <Axes: >
