# %%
# %load_ext autoreload
# %autoreload 2
from od.variables import *
from od.place import Place
from od.stats import Stats

# %%
place_name = 'Konstanz, Germany'
city = Place(place_name)
stats = Stats(city)
# Out:
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /home/nicod/.local/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)

# %%
stats.load_all()

# %%
stats.demographic
# Out:
#    nuts3  age_under_20  age_between_20_64  age_over_64  \
# 0  DE138      0.187513           0.596934     0.215552
# 1  DE147      0.187409           0.579400     0.233191
#
#    employment_rate_between_20_64  employment_rate_over_64  Agriculture  \
# 0                           83.7                     11.5     0.058188
# 1                           84.3                     12.1     0.071245
#
#    Industry  Construction  \
# 0  0.731622      0.192448
# 1  0.793604      0.122489
#
#    Wholesale, retail trade, transport, accomodation and food service  ...  \
# 0                                           0.006298                  ...
# 1                                           0.004495                  ...
#
#    Professional, scientific and technical, administrative  \
# 0                                            0.00255
# 1                                            0.00182
#
#    Public administration, defence, education, health, social  \
# 0                                           0.006459
# 1                                           0.004610
#
#    Arts, entertainment, other service  vehicle_bus  vehicle_car  vehicle_moto  \
# 0                            0.001323     0.001077     0.730357      0.079856
# 1                            0.000944     0.001276     0.771499      0.090595
#
#    vehicle_special  vehicle_utilities  vehicle_truck  household_income
# 0         0.004138           0.051666       0.047528           28000.0
# 1         0.004386           0.053071       0.048685           28500.0
#
# [2 rows x 23 columns]
